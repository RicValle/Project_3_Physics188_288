# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

rng = np.random.default_rng()

# %% [markdown]
# # Model

# %%
class Model(nn.Module):
    def __init__(self, layer_sizes, output_bound=None, dropout_rate=0.2):
        super(Model, self).__init__()
        if output_bound is not None:
            self.out_shift = output_bound[0]
            self.out_scale = output_bound[1] - output_bound[0]
        else:
            self.out_shift = 0
            self.out_scale = 1
        layers = []
        for in_dim, out_dim in zip(layer_sizes[:-2], layer_sizes[1:-1]):
            layers.append(nn.Linear(in_dim, out_dim))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout_rate))
        layers.append(nn.Linear(*layer_sizes[-2:]))
        if output_bound is not None:
            layers.append(nn.Sigmoid())
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        out = self.network(x)
        return self.out_scale * out + self.out_shift

# %% [markdown]
# # Model training function

# %%
def train_model(model, train_loader, val_loaders, criterion, optimizer, num_epochs, device, report_every=10):
    model.to(device)
    history = {'train_loss': []}
    for i in range(len(val_loaders)):
        history[f"val_loss_{i}"] = []
    s = time.time()

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)

            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * batch_x.size(0)

        train_loss /= len(train_loader.dataset)
        history['train_loss'].append(train_loss)

        model.eval()
        for i, val_loader in enumerate(val_loaders):
            val_loss = 0.0
            with torch.no_grad():
                for batch_x, batch_y in val_loader:
                    batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                    outputs = model(batch_x)
                    loss = criterion(outputs, batch_y)
                    val_loss += loss.item() * batch_x.size(0)
            history[f"val_loss_{i}"].append(val_loss / len(val_loader.dataset))

        # Print progress
        if (epoch + 1) % report_every == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.2e}, dt: {time.time()-s}, " +
                  ", ".join(f"Val Loss {i}: {history[f'val_loss_{i}'][-1]:.2e}" for i in range(len(val_loaders))))
            s = time.time()

    return history

# %%
# Function to plot training history
def plot_training_history(history, log_loss=False):
    """Plot training and validation loss"""
    plt.figure(figsize=(10, 5))
    plt.plot(history['train_loss'], label='train loss')
    i = 0
    while True:
        try:
            plt.plot(history[f'val_loss_{i}'], label=f'Validation Loss {i}')
            i += 1
        except KeyError:
            break
    plt.xlabel('epoch')
    if log_loss:
        plt.yscale('log')
        plt.ylabel('log(loss)')
    else:
        plt.ylabel('loss')
    plt.legend()
    plt.show()

# %% [markdown]
# # Model train / eval

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %% [markdown]
# Notes to self on encoding for `train_val_test_split`:
# - pretty jank but will work well enough for our purposes
# - format is `AAABCDD`
#     - `AAA` is (1-p) as percentage, e.g. `100` is the completely undiluted lattice
#     - `B` is `is_lr` (just `0` or `1` for now)
#     - `C` is lattice type
#     - `DD` is the index of the disorder configuration; currently we only use `00-09` but I'm adding enough for up to 100 configs if desired
# - nice property of this is that the 0% dilution lattices can be checked with `enc >= 1000000`
# - simple arithmetic to test for other conditions, e.g.
#     - `enc % 100` gives disorder config index

# %%
def train_val_test_split(X, Y, config_indices, train_frac=0.7, val_frac=0.15, holdout_val_frac=0.5):
    """
    does a compliated train-val-test split because we want to test both generalization across walks on previously-seen
    disorder, and generalization to unseen disorder configurations. returns 10 (!) different datasets, namely:
    - X_train, y_train: training data, obviously
    - X_val_1, y_val_1: validation data, same disorder configs as training data
    - X_val_2, y_val_2: validation data, one completely held-out disorder config
    - X_test_1, y_test_1: test data, same disorder configs as training data
    - X_test_2, y_test_2: testing data, same held-out disorder config as val_2
    specification of split sizes is a bit complicated...
    - one disorder config for each nonzero-dilution lattice type held out, regardless of size
        - this set is split according to holdout_val_frac to make val_2 and test_2
    - among the remaining disorder configs, split according to train_frac and val_frac to produce the training
        as well as val_1 / test_1 datasets

    return order:
        X_train, (X_val_1, X_val_2), (X_test_1, X_test_2), [same order for y]
    """
    
    y_enc = Y[:,1]*10000 + Y[:,2]*1000 + Y[:,0]*100 + config_indices

    # we hold out one disorder configuration to check generalization on an unseen disorder realization
    is_config_1 = (y_enc % 100 == 1)
    
    reserve_indices = np.where(is_config_1)[0]
    nonreserve_indices = np.where(~is_config_1)[0]

    y_enc_reserved = y_enc[reserve_indices]
    y_enc_nonreserved = y_enc[nonreserve_indices]
    idx_val_2, idx_test_2, _, _ = train_test_split(reserve_indices, y_enc_reserved, stratify=y_enc_reserved, train_size=holdout_val_frac)
    idx_train, idx_trainval, _, _ = train_test_split(nonreserve_indices, y_enc_nonreserved, stratify=y_enc_nonreserved, train_size=train_frac)

    y_enc_trainval = y_enc[idx_trainval]
    idx_val_1, idx_test_1, _, _ = train_test_split(idx_trainval, y_enc_trainval, stratify=y_enc_trainval, train_size=(val_frac/(1-train_frac)))

    # verify non-overlapping indices
    check_indices = np.zeros(y_enc.size, dtype=int)
    for idx in (idx_train, idx_val_1, idx_val_2, idx_test_1, idx_test_2):
        check_indices[idx] += 1
    bad = np.where(check_indices != 1)[0]
    if len(bad) > 0:
        print("WARNING: overlapping or missing indices after split")
        print(f"# of missing indices: {len(np.where(check_indices == 0)[0])}")
        print(f"# of overcounted indices: {len(np.where(check_indices > 1)[0])}")
    
    return (
        X[idx_train],
        (X[idx_val_1], X[idx_val_2]),
        (X[idx_test_1], X[idx_test_2]),
        Y[idx_train],
        (Y[idx_val_1], Y[idx_val_2]),
        (Y[idx_test_1], Y[idx_test_2]),
    )

# %%
data = np.load('featurized_data.npz')
X = data['features']
Y = data['labels']
config_indices = data['config_indices']

X = X.astype(np.float32)

N_FEATURES = X.shape[1]

# %% [markdown]
# # select which feature to train on:
# too lazy to do this the proper way, so change this flag to modify what gets trained/saved:

# %%
SELECT = 1

LABEL_NAMES = ['lattice_type', 'p', 'is_lr']
IS_REGRESSION = [False, True, False]
OUTPUT_BOUNDS = [None, (0,100), None]
NETWORK_PARAMS = [
    [N_FEATURES, 64, 4],
    [N_FEATURES, 64, 64, 64, 1],
    [N_FEATURES, 10, 2],
]
LABEL_DTYPE = [np.int64, np.float32, np.int64]
DROPOUTS = [0.1, 0.1, 0.0]
LRS = [1e-3, 1e-3, 1e-3]
WDS = [1e-5, 1e-5, 1e-5]
EPOCHS = [30, 75, 5]
CLASS_NAMES = [
    np.load('data_packed.npz')['lattice_names'],
    None,
    ["nearest-neighbor", "long-range"]
]

print(f"training to predict {LABEL_NAMES[SELECT]}")
Y = Y.astype(LABEL_DTYPE[SELECT])
# Out:
# training to predict p

# %%
X_train, X_vals, X_tests, y_train, y_vals, y_tests = \
    train_val_test_split(X, Y, config_indices)

y_train = y_train[:,SELECT]
y_vals = [y_val[:,SELECT] for y_val in y_vals]
y_tests = [y_test[:,SELECT] for y_test in y_tests]

if IS_REGRESSION[SELECT]:
    y_train = y_train[:,None]
    y_vals = [y_val[:,None] for y_val in y_vals]
    y_tests = [y_test[:,None] for y_test in y_tests]

# %%
# Create PyTorch datasets and dataloaders
train_dataset = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
val_datasets = [TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val)) for X_val, y_val in zip(X_vals, y_vals)]

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loaders = [DataLoader(vd, batch_size=batch_size, shuffle=False) for vd in val_datasets]

print(f'Number of training batches: {len(train_loader)}')
print(f'Number of validation batches: {list(map(len, val_loaders))}')
# Out:
# Number of training batches: 1596
# Number of validation batches: [342, 93]

# %%
model = Model(
    layer_sizes=NETWORK_PARAMS[SELECT],
    dropout_rate=DROPOUTS[SELECT],
    output_bound=OUTPUT_BOUNDS[SELECT],
)
print(model)
print(f'\nTotal parameters: {sum(p.numel() for p in model.parameters())}')
# Out:
# Model(
#   (network): Sequential(
#     (0): Linear(in_features=17, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=64, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )
#
# Total parameters: 9537

# %%
criterion = nn.MSELoss() if IS_REGRESSION[SELECT] else nn.CrossEntropyLoss()
#criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LRS[SELECT], weight_decay=WDS[SELECT])
print(f"using criterion: {criterion}")
# Out:
# using criterion: MSELoss()

# %% [markdown]
# # Actual training loop

# %%
num_epochs = EPOCHS[SELECT]

history = train_model(
    model=model,
    train_loader=train_loader,
    val_loaders=val_loaders,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=num_epochs,
    device=device,
    report_every=1
)
# Out:
# Epoch [1/75], Train Loss: 1.91e+02, dt: 4.02574610710144, Val Loss 0: 8.11e+01, Val Loss 1: 9.45e+01
# Epoch [2/75], Train Loss: 7.59e+01, dt: 4.316918849945068, Val Loss 0: 4.02e+01, Val Loss 1: 5.09e+01
# Epoch [3/75], Train Loss: 4.67e+01, dt: 4.468441009521484, Val Loss 0: 2.93e+01, Val Loss 1: 3.85e+01
# Epoch [4/75], Train Loss: 3.06e+01, dt: 4.4965691566467285, Val Loss 0: 1.13e+01, Val Loss 1: 1.47e+01
# Epoch [5/75], Train Loss: 1.97e+01, dt: 4.486528158187866, Val Loss 0: 7.76e+00, Val Loss 1: 9.77e+00
# Epoch [6/75], Train Loss: 1.42e+01, dt: 4.539275646209717, Val Loss 0: 5.76e+00, Val Loss 1: 7.51e+00
# Epoch [7/75], Train Loss: 1.18e+01, dt: 4.469406843185425, Val Loss 0: 5.81e+00, Val Loss 1: 7.58e+00
# Epoch [8/75], Train Loss: 9.88e+00, dt: 4.41150975227356, Val Loss 0: 9.46e+00, Val Loss 1: 1.20e+01
# Epoch [9/75], Train Loss: 8.66e+00, dt: 4.447642803192139, Val Loss 0: 4.49e+00, Val Loss 1: 6.18e+00
# Epoch [10/75], Train Loss: 8.67e+00, dt: 4.495242595672607, Val Loss 0: 7.01e+00, Val Loss 1: 8.29e+00
# Epoch [11/75], Train Loss: 8.82e+00, dt: 4.432326793670654, Val Loss 0: 6.42e+00, Val Loss 1: 8.66e+00
# Epoch [12/75], Train Loss: 7.71e+00, dt: 4.3821330070495605, Val Loss 0: 5.68e+00, Val Loss 1: 5.90e+00
# Epoch [13/75], Train Loss: 8.93e+00, dt: 4.427537679672241, Val Loss 0: 5.65e+00, Val Loss 1: 7.62e+00
# Epoch [14/75], Train Loss: 7.03e+00, dt: 4.442049741744995, Val Loss 0: 2.32e+00, Val Loss 1: 2.67e+00
# Epoch [15/75], Train Loss: 7.29e+00, dt: 4.456001281738281, Val Loss 0: 7.43e+00, Val Loss 1: 9.79e+00
# Epoch [16/75], Train Loss: 6.52e+00, dt: 4.483452081680298, Val Loss 0: 3.42e+00, Val Loss 1: 4.24e+00
# Epoch [17/75], Train Loss: 6.60e+00, dt: 4.488902807235718, Val Loss 0: 9.65e+00, Val Loss 1: 1.29e+01
# Epoch [18/75], Train Loss: 7.02e+00, dt: 4.468914747238159, Val Loss 0: 3.07e+00, Val Loss 1: 3.84e+00
# Epoch [19/75], Train Loss: 6.93e+00, dt: 4.4852869510650635, Val Loss 0: 1.25e+01, Val Loss 1: 1.48e+01
# Epoch [20/75], Train Loss: 6.44e+00, dt: 4.5041351318359375, Val Loss 0: 3.46e+00, Val Loss 1: 4.64e+00
# Epoch [21/75], Train Loss: 5.99e+00, dt: 4.5578837394714355, Val Loss 0: 2.64e+00, Val Loss 1: 3.36e+00
# Epoch [22/75], Train Loss: 5.86e+00, dt: 4.576094388961792, Val Loss 0: 4.55e+00, Val Loss 1: 4.80e+00
# Epoch [23/75], Train Loss: 5.98e+00, dt: 4.622865915298462, Val Loss 0: 1.87e+00, Val Loss 1: 2.36e+00
# Epoch [24/75], Train Loss: 6.06e+00, dt: 4.730433225631714, Val Loss 0: 3.04e+00, Val Loss 1: 3.03e+00
# Epoch [25/75], Train Loss: 6.00e+00, dt: 4.669488191604614, Val Loss 0: 2.77e+00, Val Loss 1: 3.34e+00
# Epoch [26/75], Train Loss: 5.14e+00, dt: 4.6633665561676025, Val Loss 0: 4.03e+00, Val Loss 1: 4.77e+00
# Epoch [27/75], Train Loss: 7.24e+00, dt: 4.808981895446777, Val Loss 0: 2.27e+00, Val Loss 1: 2.48e+00
# Epoch [28/75], Train Loss: 5.64e+00, dt: 4.776197910308838, Val Loss 0: 2.97e+00, Val Loss 1: 3.56e+00
# Epoch [29/75], Train Loss: 5.14e+00, dt: 4.848907709121704, Val Loss 0: 3.47e+00, Val Loss 1: 3.97e+00
# Epoch [30/75], Train Loss: 5.48e+00, dt: 4.765386581420898, Val Loss 0: 3.54e+00, Val Loss 1: 4.63e+00
# Epoch [31/75], Train Loss: 4.68e+00, dt: 4.722583293914795, Val Loss 0: 2.32e+00, Val Loss 1: 2.82e+00
# Epoch [32/75], Train Loss: 5.53e+00, dt: 4.656036853790283, Val Loss 0: 2.68e+00, Val Loss 1: 3.40e+00
# Epoch [33/75], Train Loss: 6.11e+00, dt: 4.672583818435669, Val Loss 0: 2.86e+00, Val Loss 1: 3.57e+00
# Epoch [34/75], Train Loss: 4.89e+00, dt: 4.786740064620972, Val Loss 0: 1.85e+00, Val Loss 1: 2.21e+00
# Epoch [35/75], Train Loss: 5.68e+00, dt: 4.8031699657440186, Val Loss 0: 4.95e+00, Val Loss 1: 6.62e+00
# Epoch [36/75], Train Loss: 4.71e+00, dt: 4.677894115447998, Val Loss 0: 2.69e+00, Val Loss 1: 2.97e+00
# Epoch [37/75], Train Loss: 5.58e+00, dt: 4.675181150436401, Val Loss 0: 2.07e+00, Val Loss 1: 2.29e+00
# Epoch [38/75], Train Loss: 4.29e+00, dt: 4.672518491744995, Val Loss 0: 3.93e+00, Val Loss 1: 4.93e+00
# Epoch [39/75], Train Loss: 5.48e+00, dt: 4.894958019256592, Val Loss 0: 3.12e+00, Val Loss 1: 3.63e+00
# Epoch [40/75], Train Loss: 5.30e+00, dt: 4.8157734870910645, Val Loss 0: 3.17e+00, Val Loss 1: 3.98e+00
# Epoch [41/75], Train Loss: 5.58e+00, dt: 4.698633432388306, Val Loss 0: 9.86e-01, Val Loss 1: 9.00e-01
# Epoch [42/75], Train Loss: 4.01e+00, dt: 4.750396728515625, Val Loss 0: 1.60e+00, Val Loss 1: 2.06e+00
# Epoch [43/75], Train Loss: 4.24e+00, dt: 4.789518594741821, Val Loss 0: 1.88e+00, Val Loss 1: 2.15e+00
# Epoch [44/75], Train Loss: 5.56e+00, dt: 4.712260007858276, Val Loss 0: 2.00e+00, Val Loss 1: 2.84e+00
# Epoch [45/75], Train Loss: 5.51e+00, dt: 4.688704967498779, Val Loss 0: 2.36e+00, Val Loss 1: 2.90e+00
# Epoch [46/75], Train Loss: 4.56e+00, dt: 4.79505729675293, Val Loss 0: 3.03e+00, Val Loss 1: 3.48e+00
# Epoch [47/75], Train Loss: 6.35e+00, dt: 4.789695978164673, Val Loss 0: 3.92e+00, Val Loss 1: 4.80e+00
# Epoch [48/75], Train Loss: 6.44e+00, dt: 4.7641823291778564, Val Loss 0: 1.28e+00, Val Loss 1: 1.70e+00
# Epoch [49/75], Train Loss: 4.88e+00, dt: 4.731157302856445, Val Loss 0: 2.58e+00, Val Loss 1: 3.03e+00
# Epoch [50/75], Train Loss: 4.85e+00, dt: 4.782251834869385, Val Loss 0: 1.00e+00, Val Loss 1: 8.79e-01
# Epoch [51/75], Train Loss: 3.62e+00, dt: 4.635770320892334, Val Loss 0: 1.33e+00, Val Loss 1: 1.43e+00
# Epoch [52/75], Train Loss: 5.35e+00, dt: 4.648345470428467, Val Loss 0: 1.75e+00, Val Loss 1: 2.22e+00
# Epoch [53/75], Train Loss: 4.64e+00, dt: 4.666222095489502, Val Loss 0: 9.04e-01, Val Loss 1: 1.13e+00
# Epoch [54/75], Train Loss: 5.10e+00, dt: 4.6810948848724365, Val Loss 0: 1.29e+00, Val Loss 1: 1.61e+00
# Epoch [55/75], Train Loss: 4.64e+00, dt: 4.72121262550354, Val Loss 0: 1.18e+00, Val Loss 1: 1.47e+00
# Epoch [56/75], Train Loss: 5.21e+00, dt: 4.84995436668396, Val Loss 0: 1.34e+00, Val Loss 1: 1.65e+00
# Epoch [57/75], Train Loss: 7.45e+00, dt: 4.900526762008667, Val Loss 0: 1.78e+00, Val Loss 1: 1.90e+00
# Epoch [58/75], Train Loss: 5.23e+00, dt: 4.976283073425293, Val Loss 0: 1.53e+00, Val Loss 1: 2.20e+00
# Epoch [59/75], Train Loss: 4.96e+00, dt: 4.905752420425415, Val Loss 0: 1.43e+00, Val Loss 1: 1.55e+00
# Epoch [60/75], Train Loss: 4.38e+00, dt: 4.788122892379761, Val Loss 0: 3.28e+00, Val Loss 1: 4.06e+00
# Epoch [61/75], Train Loss: 4.76e+00, dt: 4.7219557762146, Val Loss 0: 2.27e+00, Val Loss 1: 3.23e+00
# Epoch [62/75], Train Loss: 4.71e+00, dt: 4.679442405700684, Val Loss 0: 2.55e+00, Val Loss 1: 2.42e+00
# Epoch [63/75], Train Loss: 3.89e+00, dt: 4.615790843963623, Val Loss 0: 1.11e+00, Val Loss 1: 9.24e-01
# Epoch [64/75], Train Loss: 4.90e+00, dt: 4.705848693847656, Val Loss 0: 2.37e+00, Val Loss 1: 3.37e+00
# Epoch [65/75], Train Loss: 4.42e+00, dt: 4.749000310897827, Val Loss 0: 1.93e+00, Val Loss 1: 2.42e+00
# Epoch [66/75], Train Loss: 4.85e+00, dt: 4.803816318511963, Val Loss 0: 1.95e+00, Val Loss 1: 2.37e+00
# Epoch [67/75], Train Loss: 3.76e+00, dt: 4.825591802597046, Val Loss 0: 1.23e+00, Val Loss 1: 7.89e-01
# Epoch [68/75], Train Loss: 4.03e+00, dt: 4.788606405258179, Val Loss 0: 1.38e+00, Val Loss 1: 1.51e+00
# Epoch [69/75], Train Loss: 5.71e+00, dt: 4.790951728820801, Val Loss 0: 1.73e+00, Val Loss 1: 1.79e+00
# Epoch [70/75], Train Loss: 4.74e+00, dt: 4.7951743602752686, Val Loss 0: 2.02e+00, Val Loss 1: 1.61e+00
# Epoch [71/75], Train Loss: 5.16e+00, dt: 4.835358381271362, Val Loss 0: 1.93e+00, Val Loss 1: 2.34e+00
# Epoch [72/75], Train Loss: 4.43e+00, dt: 4.812111854553223, Val Loss 0: 1.54e+00, Val Loss 1: 1.92e+00
# Epoch [73/75], Train Loss: 4.59e+00, dt: 4.862017393112183, Val Loss 0: 9.63e-01, Val Loss 1: 8.74e-01
# Epoch [74/75], Train Loss: 4.65e+00, dt: 4.9388251304626465, Val Loss 0: 1.01e+00, Val Loss 1: 9.69e-01
# Epoch [75/75], Train Loss: 4.80e+00, dt: 4.987360715866089, Val Loss 0: 1.71e+00, Val Loss 1: 1.65e+00

# %%
# Plot training history
plot_training_history(history, log_loss=True)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(15,6))
model.eval()

if not IS_REGRESSION[SELECT]:
    with torch.no_grad():
        for i, (X_test, y_test, ax) in enumerate(zip(X_tests, y_tests, (ax1, ax2))):
            logits = model(torch.from_numpy(X_test).to(device)).cpu().numpy()
            predictions = np.argmax(logits, axis=1)
            print(f"test set {i} error rate: {(predictions != y_test).sum() / len(y_test):.1e}")
            cm = confusion_matrix(y_test, predictions)
            n_points_tot = cm.sum()
            cm = cm / n_points_tot
            labels = CLASS_NAMES[SELECT]
            sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=labels, yticklabels=labels, ax=ax)
            ax.set_ylabel('Actual')
            ax.set_xlabel('Predicted')
            ax.set_title(f"Test set {i} ({n_points_tot} points)")

# Or check metrics for a regressor
else:   
    percentiles = np.linspace(85,100,501,endpoint=True)  
    COLORS = [
        mcolors.to_rgb(c) for c in [
            'tab:blue',
            'tab:red',
        ]
    ]
    errors_list = []
    with torch.no_grad():
        # Example prediction on validation data
        for i, (X_test, y_test, ctuple) in enumerate(zip(X_tests, y_tests, COLORS)):
            X_test_torch = torch.from_numpy(X_test).to(device)
            predictions = model(X_test_torch).cpu().numpy()
            errors = (predictions - y_test)
            errors_list.append(errors)
            print(f"SUMMARY STATISTICS, TEST SET {i}:")
            print(f"number of points: {len(errors)}")
            print(f"MSE: {(errors**2).mean():.2f}")
            print(f"MAE: {abs(errors).mean():.2f}")
            print(f"max. abs. err.: {abs(errors).max():.2f}")
            print("")
            ax1.hist(
                errors,
                label=f"set {i}",
                range=(-25,25),
                histtype='stepfilled',
                facecolor=ctuple+(0.5,),
                edgecolor=ctuple,
                density=True
            )
            ax1.set_xlabel("error")
            ax1.set_ylabel("density")
    
            ax1.set_title("error distributions")
            ax2.set_title("absolute error, percentiles")
            ax2.plot(percentiles, np.percentile(abs(errors), percentiles), label=f"set {i}", c=ctuple)
            ax2.set_xlabel("percentile")
            ax2.set_ylabel("absolute error")
            ax2.grid(axis='x')
            ax1.legend()
            ax2.legend()
        plt.show()
        ERR_THRESH = 5
        for i, err in enumerate(errors_list):
            big_err = (abs(err)>ERR_THRESH).sum()
            print(f"set {i} |err| > {ERR_THRESH} count: {big_err:<3} ({100*big_err/len(err):.2f}%)")

plt.savefig(f"Plots/model_perf_{LABEL_NAMES[SELECT]}.png")
plt.show()
# Out:
# SUMMARY STATISTICS, TEST SET 0:
# number of points: 43764
# MSE: 1.72
# MAE: 0.51
# max. abs. err.: 48.33
#
# SUMMARY STATISTICS, TEST SET 1:
# number of points: 11779
# MSE: 1.76
# MAE: 0.69
# max. abs. err.: 26.81
# set 0 |err| > 5 count: 253 (0.58%)
# set 1 |err| > 5 count: 98  (0.83%)

# %%
# Save the model
model_name = f"model_{LABEL_NAMES[SELECT]}.pth"
torch.save(model.state_dict(), model_name)
print(f"Model saved to {model_name}")

# Load the model (example)
# model_loaded = FCN(input_dim, hidden_dims, output_dim, dropout_rate)
# model_loaded.load_state_dict(torch.load('fcn_model.pth'))
# model_loaded.to(device)
# model_loaded.eval()
# Out:
# Model saved to model_p.pth
