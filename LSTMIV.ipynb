# %% [markdown]
# ## LSTM with average trajectories from the dataset

# %%
import numpy as np
from scipy.interpolate import interp1d
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import math
import random

def pad(data):
    """
    pad data with np.nan (for data that is a list of arrays of different sizes).
    """
    
    x = len(data)
    y = max(len(arr) for arr in data)
    padded_data = np.full((x, y), np.nan)
    for i in range(x):
        padded_data[i, :len(data[i])] = data[i]
    return padded_data

def pad_2(data):
    """
    Pad a list of 2-column arrays (shape = [L_i, 2]) with np.nan 
    so they become a single array of shape (N, max_len, 2).
    """
    N = len(data)
    max_len = max(arr.shape[0] for arr in data)   # longest trajectory
    D = data[0].shape[1]                          # should be 2
    
    padded_data = np.full((N, max_len, D), np.nan)
    
    for i, arr in enumerate(data):
        length = arr.shape[0]
        padded_data[i, :length, :] = arr
    
    return padded_data

def contribution_threshold(data, cutoff_fraction):
    """
    Find the time index where certain fraction of the trajectories contribute.
    Basically, some random walkers will get stuck at a site for a long time and overshoot t_max
    by a lot. So time points will only have a few trajectories contributing to the ensemble average, 
    making it not a good statistical average/too small of a sample size.
    """
    data_arr = np.array(data)
    n_trajectories = data_arr.shape[0]
    min_required = int(cutoff_fraction * n_trajectories)  
    valid_counts = np.sum(~np.isnan(data), axis=0)
    cutoff_idx = np.where(valid_counts < min_required)[0]
    if len(cutoff_idx) > 0:
        last_valid_idx = cutoff_idx[0]
    else:
        last_valid_idx = data_arr.shape[1]
        
    return last_valid_idx


def average_trajectories(trajectories, t_max):
    """
    Carefully calculate averages of different variables over different random walkers 
    and different lattice configurations. 
    This is nontrivial since each random walker hops at different time points.
    """
    
    all_squared_displacements = [traj['sq_disp'] for traj in trajectories]
    all_times = [traj['times'] for traj in trajectories]
    all_distinct_sites = [traj['distinct_sites'] for traj in trajectories]

    #MSD vs steps
    padded_disp = pad(all_squared_displacements)
    msd_vs_steps = np.nanmean(padded_disp, axis=0)
    last_valid_idx = contribution_threshold(padded_disp, 0.8)
    msd_vs_steps = msd_vs_steps[:last_valid_idx]

    #MSD vs time
    from scipy.interpolate import interp1d

    t_bins = np.linspace(0, t_max, last_valid_idx)
    all_interp_disp = []
    for times, sq_disp in zip(all_times, all_squared_displacements):
        times = np.array(times)
        sq_disp = np.array(sq_disp)
        valid_mask = times <= t_max
        f = interp1d(times[valid_mask], sq_disp[valid_mask],
                     kind='previous', bounds_error=False, fill_value=np.nan)
        interp_disp = f(t_bins)
        all_interp_disp.append(interp_disp)

    msd_vs_time = np.nanmean(all_interp_disp, axis=0)
    last_valid_idx_time = contribution_threshold(all_interp_disp, 0.8)
    t_bins = t_bins[:last_valid_idx_time]
    msd_vs_time = msd_vs_time[:last_valid_idx_time]

    #Distinct sites visited vs steps
    padded_distinct_sites = pad(all_distinct_sites)
    distinct_sites_vs_steps = np.nanmean(padded_distinct_sites, axis=0)
    last_valid_idx_sites = contribution_threshold(padded_distinct_sites, 0.8)
    distinct_sites_vs_steps = distinct_sites_vs_steps[:last_valid_idx_sites]

    return msd_vs_steps, msd_vs_time, t_bins, distinct_sites_vs_steps

# %%
def build_features_for_trajectory(trajectories, t_max, seq_len, add_derivative=False):
    """
    Return features shape (seq_len, n_features) for one trajectory.
    Features: sq_disp, distinct_sites (and optional derivative of sq_disp).
    """
    seq_sq = trajectories['sq_disp']
    seq_sites =trajectories['distinct_sites']
    features = [seq_sq, seq_sites]
    # stack features -> (seq_len, n_features)
    feat = np.vstack(features).T.astype(np.float32)
    return feat

def build_dataset_from_trajectories(trajectories, labels, t_max=150.0, seq_len=200):
    """
    trajectories: list of dicts
    labels: dict with keys 'lattice', 'p', 'longrange' each a list/array of ints aligned with trajectories
    Returns: X (N, seq_len, n_features), y1,y2,y3 (N,)
    """
    N = len(trajectories)
    y1 = np.array(labels['lattice'], dtype=np.int64)
    y2 = np.array(labels['p'], dtype=np.int64)
    y3 = np.array(labels['longrange'], dtype=np.int64)
    X = [build_features_for_trajectory(traj,t_max, seq_len) for traj in trajectories]
    return X, y1, y2, y3

# %%
t_max = 150.0
seq_len = 200
trajectories = []
labels = {'lattice':[], 'conc':[], 'coupling':[]}

import os
import re
import numpy as np
import pandas as pd

data_folder = r"C:\Users\Ke\Documents\GithubRepo\Project_3_Physics188_288\Data"

pattern = re.compile(
    r"(?P<lat>BCC|diamond|FCC|SC)_p=(?P<p>\d+)%_(?P<int>alpha=6|nearestneighbor)\.npz"
)

records = []
data_list = []

for fname in os.listdir(data_folder):
    match = pattern.match(fname)
    if not match:
        print("Skipping invalid file:", fname)
        continue
    
    lattice_str = match.group("lat")
    if lattice_str == "BCC":
        lattice = 0
    elif lattice_str =="diamond":
        lattice = 1
    elif lattice_str == "FCC":
        lattice = 2
    else: # "SC"
        lattice = 3  # unknown

    p = float(match.group("p")) / 100.0
    
    longrange_str = match.group("int")

    longrange = 1 if longrange_str == "alpha=6" else 0

    file_path = os.path.join(data_folder, fname)
    data = np.load(file_path, allow_pickle=True)

    results = data['results']

    # divide the trajectories data into different block and average over each block, make sure block_size \times num_blocks = 10,000
    block_size = 100
    num_blocks = 100

    for i in range(num_blocks):
        start = i * block_size
        end = (i + 1) * block_size
        trajectories_temp = results[start:end]
        # results = data[list(data.keys())[0]]
        msd_vs_steps, msd_vs_time, t_bins, distinct_sites_vs_steps = average_trajectories(trajectories_temp, t_max)
        n_steps = np.arange(0, len(msd_vs_steps))
        # print(len(distinct_sites_vs_steps))

        trajectories.append({'steps':n_steps, 'sq_disp':msd_vs_steps, 'distinct_sites':distinct_sites_vs_steps})
        records.append({
            "filename": fname,
            "lattice": lattice,
            "p": p,
            "longrange": longrange
        })
labels = pd.DataFrame(records)
# Out:
# C:\Users\Ke\AppData\Local\Temp\ipykernel_16676\4278322791.py:92: RuntimeWarning: Mean of empty slice
#   msd_vs_time = np.nanmean(all_interp_disp, axis=0)
# Skipping invalid file: README.md
# Skipping invalid file: test

# %%
import numpy as np
from keras import optimizers
from keras.layers import LSTM, Dense, Dropout, Masking
from keras.models import Sequential
from keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input
from keras.callbacks import EarlyStopping

# ============================================================
# VARIABLE-LENGTH DATA
# ============================================================

num_samples = 3200
F = 2
num_outputs = 3     # because y.shape = (N, 3)

X_list, y1, y2, y3 = build_dataset_from_trajectories(trajectories, labels, t_max=t_max, seq_len=seq_len)
y = np.stack([y1, y2, y3], axis=1)

# ============================================================
# FEATURE-WISE MINMAX SCALING
# ============================================================

scaler = MinMaxScaler()

X_concat = np.vstack(X_list)
X_scaled = scaler.fit_transform(X_concat)

X_list_scaled = []
idx = 0
for seq in X_list:
    Ti = seq.shape[0]
    X_list_scaled.append(X_scaled[idx:idx+Ti])
    idx += Ti

# ============================================================
# PADDING
# ============================================================

max_len = max(seq.shape[0] for seq in X_list_scaled)

X_padded = pad_sequences(
    X_list_scaled,
    maxlen=max_len,
    dtype="float32",
    padding="post",
    truncating="post",
    value=0.0
)

print("Padded X:", X_padded.shape)




# ============================================================
# TRAIN / VALIDATION SPLIT
# ============================================================

y1_original = y[:, 0] # 4 Class
y2_original = y[:, 1].reshape(-1, 1) # Regression
y3_original = y[:, 2].reshape(-1, 1) # Two Class
y1_onehot = to_categorical(y1_original, num_classes=4)

X_train, X_val, y1_train, y1_val, y2_train, y2_val, y3_train, y3_val = train_test_split( X_padded, y1_onehot, y2_original, y3_original, test_size=0.1, random_state=42 ) 
print(f"X_train shape: {X_train.shape}") 
print(f"y1_train shape (4 Class): {y1_train.shape}") 
print(f"y2_train shape (Regression): {y2_train.shape}") 
print(f"y3_train shape (Two Class): {y3_train.shape}")


# ============================================================
# TRAIN MODEL
# ============================================================


input_tensor = Input(shape=(max_len, F)) 
x = Masking(mask_value=0.0)(input_tensor) 
# x = LSTM(64, return_sequences=True)(x) 
# x = Dropout(0.3)(x) 
x = LSTM(32)(x)
output_y1 = Dense(4, activation='softmax', name='y1_classifier')(x) 
output_y2 = Dense(1, activation='relu', name='y2_regressor')(x) 
output_y3 = Dense(1, activation='sigmoid', name='y3_binary')(x) 
model = Model(inputs=input_tensor, outputs=[output_y1, output_y2, output_y3])
optimizer = optimizers.Adam(learning_rate=1e-3) 
model.compile( optimizer=optimizer, 
                loss={ 'y1_classifier': 'categorical_crossentropy',
                    'y2_regressor': 'mse',
                    'y3_binary': 'binary_crossentropy'        
                    }, 
                metrics={ 'y1_classifier': ['accuracy'], 'y2_regressor': ['mae'], 'y3_binary': ['accuracy'] } )
model.summary()

early_stopping = EarlyStopping( monitor='val_loss',
                               patience=5,
                               restore_best_weights=True, verbose=1 ) 
history = model.fit( X_train, 
                    [y1_train, y2_train, y3_train], 
                    validation_data=(X_val, [y1_val, y2_val, y3_val]), 
                    epochs=100, 
                    batch_size=32, verbose=1, callbacks=[early_stopping] )
# Out:
# Padded X: (3200, 236, 2)
# X_train shape: (2880, 236, 2)
# y1_train shape (4 Class): (2880, 4)
# y2_train shape (Regression): (2880, 1)
# y3_train shape (Two Class): (2880, 1)
# Model: "functional_188"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_55      │ (None, 236, 2)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_190       │ (None, 236, 2)    │          0 │ input_layer_55[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_55          │ (None, 236, 2)    │          0 │ input_layer_55[0… │
# │ (Masking)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_190 (Any)       │ (None, 236)       │          0 │ not_equal_190[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_78 (LSTM)      │ (None, 32)        │      4,480 │ masking_55[0][0], │
# │                     │                   │            │ any_190[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_classifier       │ (None, 4)         │        132 │ lstm_78[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_regressor        │ (None, 1)         │         33 │ lstm_78[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y3_binary (Dense)   │ (None, 1)         │         33 │ lstm_78[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,678 (18.27 KB)
#  Trainable params: 4,678 (18.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 2.0843 - y1_classifier_accuracy: 0.3601 - y1_classifier_loss: 1.3107 - y2_regressor_loss: 0.1678 - y2_regressor_mae: 0.3285 - y3_binary_accuracy: 0.7427 - y3_binary_loss: 0.6058 - val_loss: 1.8119 - val_y1_classifier_accuracy: 0.4781 - val_y1_classifier_loss: 1.1918 - val_y2_regressor_loss: 0.1481 - val_y2_regressor_mae: 0.3188 - val_y3_binary_accuracy: 0.8281 - val_y3_binary_loss: 0.4720
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.7649 - y1_classifier_accuracy: 0.4993 - y1_classifier_loss: 1.0904 - y2_regressor_loss: 0.1508 - y2_regressor_mae: 0.3130 - y3_binary_accuracy: 0.7795 - y3_binary_loss: 0.5238 - val_loss: 1.6240 - val_y1_classifier_accuracy: 0.4406 - val_y1_classifier_loss: 1.0133 - val_y2_regressor_loss: 0.1447 - val_y2_regressor_mae: 0.3110 - val_y3_binary_accuracy: 0.8156 - val_y3_binary_loss: 0.4661
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.5876 - y1_classifier_accuracy: 0.5552 - y1_classifier_loss: 0.9502 - y2_regressor_loss: 0.1337 - y2_regressor_mae: 0.2773 - y3_binary_accuracy: 0.7604 - y3_binary_loss: 0.5037 - val_loss: 1.4402 - val_y1_classifier_accuracy: 0.6094 - val_y1_classifier_loss: 0.8452 - val_y2_regressor_loss: 0.1282 - val_y2_regressor_mae: 0.2659 - val_y3_binary_accuracy: 0.8219 - val_y3_binary_loss: 0.4668
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.4459 - y1_classifier_accuracy: 0.5701 - y1_classifier_loss: 0.8433 - y2_regressor_loss: 0.1110 - y2_regressor_mae: 0.2448 - y3_binary_accuracy: 0.7799 - y3_binary_loss: 0.4915 - val_loss: 1.3449 - val_y1_classifier_accuracy: 0.5813 - val_y1_classifier_loss: 0.8176 - val_y2_regressor_loss: 0.0945 - val_y2_regressor_mae: 0.2257 - val_y3_binary_accuracy: 0.8375 - val_y3_binary_loss: 0.4328
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.4596 - y1_classifier_accuracy: 0.6389 - y1_classifier_loss: 0.8003 - y2_regressor_loss: 0.1003 - y2_regressor_mae: 0.2262 - y3_binary_accuracy: 0.7462 - y3_binary_loss: 0.5590 - val_loss: 1.3678 - val_y1_classifier_accuracy: 0.6531 - val_y1_classifier_loss: 0.7757 - val_y2_regressor_loss: 0.0861 - val_y2_regressor_mae: 0.2035 - val_y3_binary_accuracy: 0.7969 - val_y3_binary_loss: 0.5061
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.3660 - y1_classifier_accuracy: 0.6639 - y1_classifier_loss: 0.7757 - y2_regressor_loss: 0.0811 - y2_regressor_mae: 0.1805 - y3_binary_accuracy: 0.7375 - y3_binary_loss: 0.5091 - val_loss: 1.2590 - val_y1_classifier_accuracy: 0.6469 - val_y1_classifier_loss: 0.7530 - val_y2_regressor_loss: 0.0632 - val_y2_regressor_mae: 0.1613 - val_y3_binary_accuracy: 0.8250 - val_y3_binary_loss: 0.4428
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2244 - y1_classifier_accuracy: 0.6663 - y1_classifier_loss: 0.7251 - y2_regressor_loss: 0.0611 - y2_regressor_mae: 0.1434 - y3_binary_accuracy: 0.8125 - y3_binary_loss: 0.4382 - val_loss: 1.1797 - val_y1_classifier_accuracy: 0.7125 - val_y1_classifier_loss: 0.7078 - val_y2_regressor_loss: 0.0740 - val_y2_regressor_mae: 0.1524 - val_y3_binary_accuracy: 0.8531 - val_y3_binary_loss: 0.3979
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1568 - y1_classifier_accuracy: 0.7069 - y1_classifier_loss: 0.6890 - y2_regressor_loss: 0.0593 - y2_regressor_mae: 0.1373 - y3_binary_accuracy: 0.8167 - y3_binary_loss: 0.4085 - val_loss: 1.1370 - val_y1_classifier_accuracy: 0.7125 - val_y1_classifier_loss: 0.6895 - val_y2_regressor_loss: 0.0655 - val_y2_regressor_mae: 0.1404 - val_y3_binary_accuracy: 0.8687 - val_y3_binary_loss: 0.3819
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.0732 - y1_classifier_accuracy: 0.7510 - y1_classifier_loss: 0.6483 - y2_regressor_loss: 0.0516 - y2_regressor_mae: 0.1255 - y3_binary_accuracy: 0.8226 - y3_binary_loss: 0.3734 - val_loss: 1.0520 - val_y1_classifier_accuracy: 0.7875 - val_y1_classifier_loss: 0.6324 - val_y2_regressor_loss: 0.0577 - val_y2_regressor_mae: 0.1219 - val_y3_binary_accuracy: 0.8375 - val_y3_binary_loss: 0.3620
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.0733 - y1_classifier_accuracy: 0.7451 - y1_classifier_loss: 0.6426 - y2_regressor_loss: 0.0597 - y2_regressor_mae: 0.1266 - y3_binary_accuracy: 0.8250 - y3_binary_loss: 0.3709 - val_loss: 1.1061 - val_y1_classifier_accuracy: 0.7719 - val_y1_classifier_loss: 0.6116 - val_y2_regressor_loss: 0.0626 - val_y2_regressor_mae: 0.1282 - val_y3_binary_accuracy: 0.8031 - val_y3_binary_loss: 0.4320
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.3461 - y1_classifier_accuracy: 0.6538 - y1_classifier_loss: 0.7999 - y2_regressor_loss: 0.1018 - y2_regressor_mae: 0.1854 - y3_binary_accuracy: 0.8017 - y3_binary_loss: 0.4444 - val_loss: 1.2224 - val_y1_classifier_accuracy: 0.6375 - val_y1_classifier_loss: 0.7482 - val_y2_regressor_loss: 0.0762 - val_y2_regressor_mae: 0.1717 - val_y3_binary_accuracy: 0.8438 - val_y3_binary_loss: 0.3979
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1577 - y1_classifier_accuracy: 0.6816 - y1_classifier_loss: 0.7180 - y2_regressor_loss: 0.0628 - y2_regressor_mae: 0.1442 - y3_binary_accuracy: 0.8507 - y3_binary_loss: 0.3769 - val_loss: 1.1205 - val_y1_classifier_accuracy: 0.6844 - val_y1_classifier_loss: 0.6953 - val_y2_regressor_loss: 0.0671 - val_y2_regressor_mae: 0.1540 - val_y3_binary_accuracy: 0.8719 - val_y3_binary_loss: 0.3580
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1031 - y1_classifier_accuracy: 0.6878 - y1_classifier_loss: 0.6933 - y2_regressor_loss: 0.0638 - y2_regressor_mae: 0.1418 - y3_binary_accuracy: 0.8663 - y3_binary_loss: 0.3460 - val_loss: 1.0317 - val_y1_classifier_accuracy: 0.6969 - val_y1_classifier_loss: 0.6653 - val_y2_regressor_loss: 0.0578 - val_y2_regressor_mae: 0.1527 - val_y3_binary_accuracy: 0.9031 - val_y3_binary_loss: 0.3086
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.2966 - y1_classifier_accuracy: 0.6458 - y1_classifier_loss: 0.8292 - y2_regressor_loss: 0.0809 - y2_regressor_mae: 0.1641 - y3_binary_accuracy: 0.8413 - y3_binary_loss: 0.3866 - val_loss: 1.1980 - val_y1_classifier_accuracy: 0.6750 - val_y1_classifier_loss: 0.7469 - val_y2_regressor_loss: 0.0659 - val_y2_regressor_mae: 0.1534 - val_y3_binary_accuracy: 0.8594 - val_y3_binary_loss: 0.3853
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.0675 - y1_classifier_accuracy: 0.7090 - y1_classifier_loss: 0.6632 - y2_regressor_loss: 0.0594 - y2_regressor_mae: 0.1335 - y3_binary_accuracy: 0.8503 - y3_binary_loss: 0.3449 - val_loss: 0.9799 - val_y1_classifier_accuracy: 0.7250 - val_y1_classifier_loss: 0.6173 - val_y2_regressor_loss: 0.0702 - val_y2_regressor_mae: 0.1615 - val_y3_binary_accuracy: 0.8969 - val_y3_binary_loss: 0.2923
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.9377 - y1_classifier_accuracy: 0.7455 - y1_classifier_loss: 0.6063 - y2_regressor_loss: 0.0556 - y2_regressor_mae: 0.1285 - y3_binary_accuracy: 0.8944 - y3_binary_loss: 0.2758 - val_loss: 0.8936 - val_y1_classifier_accuracy: 0.7312 - val_y1_classifier_loss: 0.6077 - val_y2_regressor_loss: 0.0492 - val_y2_regressor_mae: 0.1224 - val_y3_binary_accuracy: 0.9031 - val_y3_binary_loss: 0.2367
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.9134 - y1_classifier_accuracy: 0.7549 - y1_classifier_loss: 0.5813 - y2_regressor_loss: 0.0548 - y2_regressor_mae: 0.1229 - y3_binary_accuracy: 0.8747 - y3_binary_loss: 0.2773 - val_loss: 0.9341 - val_y1_classifier_accuracy: 0.7469 - val_y1_classifier_loss: 0.5778 - val_y2_regressor_loss: 0.0545 - val_y2_regressor_mae: 0.1205 - val_y3_binary_accuracy: 0.8562 - val_y3_binary_loss: 0.3019
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.8267 - y1_classifier_accuracy: 0.7510 - y1_classifier_loss: 0.5468 - y2_regressor_loss: 0.0517 - y2_regressor_mae: 0.1200 - y3_binary_accuracy: 0.9021 - y3_binary_loss: 0.2282 - val_loss: 0.7755 - val_y1_classifier_accuracy: 0.7719 - val_y1_classifier_loss: 0.5089 - val_y2_regressor_loss: 0.0483 - val_y2_regressor_mae: 0.1189 - val_y3_binary_accuracy: 0.9094 - val_y3_binary_loss: 0.2183
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.7905 - y1_classifier_accuracy: 0.7642 - y1_classifier_loss: 0.5212 - y2_regressor_loss: 0.0494 - y2_regressor_mae: 0.1176 - y3_binary_accuracy: 0.9104 - y3_binary_loss: 0.2200 - val_loss: 0.8569 - val_y1_classifier_accuracy: 0.7969 - val_y1_classifier_loss: 0.5097 - val_y2_regressor_loss: 0.0463 - val_y2_regressor_mae: 0.1099 - val_y3_binary_accuracy: 0.8594 - val_y3_binary_loss: 0.3009
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.7220 - y1_classifier_accuracy: 0.7816 - y1_classifier_loss: 0.4887 - y2_regressor_loss: 0.0446 - y2_regressor_mae: 0.1122 - y3_binary_accuracy: 0.9264 - y3_binary_loss: 0.1887 - val_loss: 0.8449 - val_y1_classifier_accuracy: 0.7656 - val_y1_classifier_loss: 0.5511 - val_y2_regressor_loss: 0.0504 - val_y2_regressor_mae: 0.1146 - val_y3_binary_accuracy: 0.9094 - val_y3_binary_loss: 0.2433
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.6855 - y1_classifier_accuracy: 0.7986 - y1_classifier_loss: 0.4621 - y2_regressor_loss: 0.0470 - y2_regressor_mae: 0.1098 - y3_binary_accuracy: 0.9316 - y3_binary_loss: 0.1763 - val_loss: 0.6623 - val_y1_classifier_accuracy: 0.8406 - val_y1_classifier_loss: 0.4369 - val_y2_regressor_loss: 0.0362 - val_y2_regressor_mae: 0.0983 - val_y3_binary_accuracy: 0.9312 - val_y3_binary_loss: 0.1891
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.6128 - y1_classifier_accuracy: 0.8146 - y1_classifier_loss: 0.4383 - y2_regressor_loss: 0.0342 - y2_regressor_mae: 0.0945 - y3_binary_accuracy: 0.9479 - y3_binary_loss: 0.1402 - val_loss: 0.5831 - val_y1_classifier_accuracy: 0.8281 - val_y1_classifier_loss: 0.4242 - val_y2_regressor_loss: 0.0258 - val_y2_regressor_mae: 0.0838 - val_y3_binary_accuracy: 0.9563 - val_y3_binary_loss: 0.1331
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.6092 - y1_classifier_accuracy: 0.8115 - y1_classifier_loss: 0.4352 - y2_regressor_loss: 0.0320 - y2_regressor_mae: 0.0872 - y3_binary_accuracy: 0.9458 - y3_binary_loss: 0.1419 - val_loss: 0.5198 - val_y1_classifier_accuracy: 0.8500 - val_y1_classifier_loss: 0.3786 - val_y2_regressor_loss: 0.0275 - val_y2_regressor_mae: 0.0817 - val_y3_binary_accuracy: 0.9625 - val_y3_binary_loss: 0.1137
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.5853 - y1_classifier_accuracy: 0.8191 - y1_classifier_loss: 0.4030 - y2_regressor_loss: 0.0345 - y2_regressor_mae: 0.0874 - y3_binary_accuracy: 0.9389 - y3_binary_loss: 0.1477 - val_loss: 0.5119 - val_y1_classifier_accuracy: 0.8438 - val_y1_classifier_loss: 0.3760 - val_y2_regressor_loss: 0.0289 - val_y2_regressor_mae: 0.0793 - val_y3_binary_accuracy: 0.9688 - val_y3_binary_loss: 0.1069
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.8092 - y1_classifier_accuracy: 0.7563 - y1_classifier_loss: 0.5565 - y2_regressor_loss: 0.0473 - y2_regressor_mae: 0.0930 - y3_binary_accuracy: 0.9257 - y3_binary_loss: 0.2053 - val_loss: 0.7945 - val_y1_classifier_accuracy: 0.8000 - val_y1_classifier_loss: 0.5353 - val_y2_regressor_loss: 0.0423 - val_y2_regressor_mae: 0.0972 - val_y3_binary_accuracy: 0.9563 - val_y3_binary_loss: 0.2169
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.8712 - y1_classifier_accuracy: 0.7528 - y1_classifier_loss: 0.6224 - y2_regressor_loss: 0.0421 - y2_regressor_mae: 0.0989 - y3_binary_accuracy: 0.9302 - y3_binary_loss: 0.2066 - val_loss: 0.8015 - val_y1_classifier_accuracy: 0.8094 - val_y1_classifier_loss: 0.5650 - val_y2_regressor_loss: 0.0496 - val_y2_regressor_mae: 0.1015 - val_y3_binary_accuracy: 0.9219 - val_y3_binary_loss: 0.1870
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.6548 - y1_classifier_accuracy: 0.8247 - y1_classifier_loss: 0.4858 - y2_regressor_loss: 0.0304 - y2_regressor_mae: 0.0727 - y3_binary_accuracy: 0.9486 - y3_binary_loss: 0.1385 - val_loss: 0.5939 - val_y1_classifier_accuracy: 0.8344 - val_y1_classifier_loss: 0.4421 - val_y2_regressor_loss: 0.0261 - val_y2_regressor_mae: 0.0667 - val_y3_binary_accuracy: 0.9531 - val_y3_binary_loss: 0.1257
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.6244 - y1_classifier_accuracy: 0.8017 - y1_classifier_loss: 0.4668 - y2_regressor_loss: 0.0283 - y2_regressor_mae: 0.0711 - y3_binary_accuracy: 0.9486 - y3_binary_loss: 0.1293 - val_loss: 0.5782 - val_y1_classifier_accuracy: 0.8500 - val_y1_classifier_loss: 0.4206 - val_y2_regressor_loss: 0.0321 - val_y2_regressor_mae: 0.0766 - val_y3_binary_accuracy: 0.9531 - val_y3_binary_loss: 0.1255
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.5533 - y1_classifier_accuracy: 0.8253 - y1_classifier_loss: 0.4072 - y2_regressor_loss: 0.0267 - y2_regressor_mae: 0.0666 - y3_binary_accuracy: 0.9542 - y3_binary_loss: 0.1193 - val_loss: 0.5406 - val_y1_classifier_accuracy: 0.8406 - val_y1_classifier_loss: 0.3772 - val_y2_regressor_loss: 0.0265 - val_y2_regressor_mae: 0.0689 - val_y3_binary_accuracy: 0.9469 - val_y3_binary_loss: 0.1369
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %%
import matplotlib.pyplot as plt

# Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['y1_classifier_loss'], label='Training Loss')
plt.plot(history.history['val_y1_classifier_loss'], label='Validation Loss')

plt.plot(history.history['y2_regressor_loss'], label='Training Loss')
plt.plot(history.history['val_y2_regressor_loss'], label='Validation Loss')

plt.plot(history.history['y3_binary_loss'], label='Training Loss')
plt.plot(history.history['val_y3_binary_loss'], label='Validation Loss')
plt.title('Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot Training and Validation Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['y1_classifier_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_y1_classifier_accuracy'], label='Validation Accuracy')

plt.plot(history.history['y2_regressor_mae'], label='Training Accuracy')
plt.plot(history.history['val_y2_regressor_mae'], label='Validation Accuracy')

plt.plot(history.history['y3_binary_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_y3_binary_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0,1])
plt.legend()
plt.grid(True)
plt.show()



model.save("lstm_multilabel_multiend_classifier2.h5")
np.save("scaler_minmax2.npy", scaler.data_min_)
print("\nModel saved as lstm_multilabel_multiend_classifier2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as lstm_multilabel_multiend_classifier2.h5

# %%
import numpy as np
from keras import optimizers
from keras.layers import LSTM, Dense, Dropout, Masking
from keras.models import Sequential
from keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input
from keras.callbacks import EarlyStopping

# ============================================================
# VARIABLE-LENGTH DATA
# ============================================================

num_samples = 3200
F = 2
num_outputs = 3     # because y.shape = (N, 3)

X_list, y1, y2, y3 = build_dataset_from_trajectories(trajectories, labels, t_max=t_max, seq_len=seq_len)
y = np.stack([y1, y2, y3], axis=1)

# ============================================================
# FEATURE-WISE MINMAX SCALING
# ============================================================

scaler = MinMaxScaler()

X_concat = np.vstack(X_list)
X_scaled = scaler.fit_transform(X_concat)

X_list_scaled = []
idx = 0
for seq in X_list:
    Ti = seq.shape[0]
    X_list_scaled.append(X_scaled[idx:idx+Ti])
    idx += Ti

# ============================================================
# PADDING
# ============================================================

max_len = max(seq.shape[0] for seq in X_list_scaled)

X_padded = pad_sequences(
    X_list_scaled,
    maxlen=max_len,
    dtype="float32",
    padding="post",
    truncating="post",
    value=0.0
)

print("Padded X:", X_padded.shape)



# ============================================================
# TRAIN / VALIDATION SPLIT
# ============================================================

y1_original = y[:, 0] # 4 Class
y2_original = y[:, 1].reshape(-1, 1) # Regression
y3_original = y[:, 2].reshape(-1, 1) # Two Class
y1_onehot = to_categorical(y1_original, num_classes=4)

X_train, X_val, y1_train, y1_val, y2_train, y2_val, y3_train, y3_val = train_test_split( X_padded, y1_onehot, y2_original, y3_original, test_size=0.1, random_state=42 ) 
print(f"X_train shape: {X_train.shape}") 
print(f"y1_train shape (4 Class): {y1_train.shape}") 
print(f"y2_train shape (Regression): {y2_train.shape}") 
print(f"y3_train shape (Two Class): {y3_train.shape}")


# ============================================================
# TRAIN MODEL
# ============================================================


input_tensor = Input(shape=(max_len, F)) 
x = Masking(mask_value=0.0)(input_tensor) 
x = LSTM(64, return_sequences=True)(x) 
x = Dropout(0.3)(x) 
x = LSTM(32)(x) 


output_y1 = Dense(4, activation='softmax', name='y1_classifier')(x) 
output_y2 = Dense(1, activation='relu', name='y2_regressor')(x) 
output_y3 = Dense(1, activation='sigmoid', name='y3_binary')(x) 
model = Model(inputs=input_tensor, outputs=[output_y1, output_y2, output_y3])
optimizer = optimizers.Adam(learning_rate=1e-3) 
model.compile( optimizer=optimizer, 
                loss={ 'y1_classifier': 'categorical_crossentropy', 
                    'y2_regressor': 'mse', 
                    'y3_binary': 'binary_crossentropy'          
                    },
                metrics={ 'y1_classifier': ['accuracy'], 'y2_regressor': ['mae'], 'y3_binary': ['accuracy'] } )
model.summary()
early_stopping = EarlyStopping( monitor='val_loss', 
                               patience=5, 
                               restore_best_weights=True, verbose=1 ) 
history = model.fit( X_train,
                    [y1_train, y2_train, y3_train], 
                    validation_data=(X_val, [y1_val, y2_val, y3_val]), 
                    epochs=100, 
                    batch_size=32, verbose=1, callbacks=[early_stopping] )
# Out:
# Padded X: (3200, 236, 2)
# X_train shape: (2880, 236, 2)
# y1_train shape (4 Class): (2880, 4)
# y2_train shape (Regression): (2880, 1)
# y3_train shape (Two Class): (2880, 1)
# Model: "functional_189"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_56      │ (None, 236, 2)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_191       │ (None, 236, 2)    │          0 │ input_layer_56[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_56          │ (None, 236, 2)    │          0 │ input_layer_56[0… │
# │ (Masking)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_191 (Any)       │ (None, 236)       │          0 │ not_equal_191[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_79 (LSTM)      │ (None, 236, 64)   │     17,152 │ masking_56[0][0], │
# │                     │                   │            │ any_191[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 236, 64)   │          0 │ lstm_79[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_80 (LSTM)      │ (None, 32)        │     12,416 │ dropout_24[0][0], │
# │                     │                   │            │ any_191[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_classifier       │ (None, 4)         │        132 │ lstm_80[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_regressor        │ (None, 1)         │         33 │ lstm_80[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y3_binary (Dense)   │ (None, 1)         │         33 │ lstm_80[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,766 (116.27 KB)
#  Trainable params: 29,766 (116.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - loss: 1.9654 - y1_classifier_accuracy: 0.4194 - y1_classifier_loss: 1.2431 - y2_regressor_loss: 0.1733 - y2_regressor_mae: 0.3254 - y3_binary_accuracy: 0.7635 - y3_binary_loss: 0.5490 - val_loss: 1.5955 - val_y1_classifier_accuracy: 0.5844 - val_y1_classifier_loss: 1.0171 - val_y2_regressor_loss: 0.1685 - val_y2_regressor_mae: 0.3030 - val_y3_binary_accuracy: 0.8438 - val_y3_binary_loss: 0.4099
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 1.4442 - y1_classifier_accuracy: 0.5979 - y1_classifier_loss: 0.8801 - y2_regressor_loss: 0.1157 - y2_regressor_mae: 0.2397 - y3_binary_accuracy: 0.8038 - y3_binary_loss: 0.4484 - val_loss: 1.2922 - val_y1_classifier_accuracy: 0.6250 - val_y1_classifier_loss: 0.7809 - val_y2_regressor_loss: 0.0894 - val_y2_regressor_mae: 0.2117 - val_y3_binary_accuracy: 0.7937 - val_y3_binary_loss: 0.4219
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 1.2494 - y1_classifier_accuracy: 0.7059 - y1_classifier_loss: 0.7310 - y2_regressor_loss: 0.0944 - y2_regressor_mae: 0.2008 - y3_binary_accuracy: 0.8031 - y3_binary_loss: 0.4239 - val_loss: 1.0849 - val_y1_classifier_accuracy: 0.8188 - val_y1_classifier_loss: 0.6265 - val_y2_regressor_loss: 0.0740 - val_y2_regressor_mae: 0.1747 - val_y3_binary_accuracy: 0.8375 - val_y3_binary_loss: 0.3844
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 1.0676 - y1_classifier_accuracy: 0.7597 - y1_classifier_loss: 0.6094 - y2_regressor_loss: 0.0736 - y2_regressor_mae: 0.1707 - y3_binary_accuracy: 0.8313 - y3_binary_loss: 0.3846 - val_loss: 1.0732 - val_y1_classifier_accuracy: 0.7219 - val_y1_classifier_loss: 0.6763 - val_y2_regressor_loss: 0.0563 - val_y2_regressor_mae: 0.1508 - val_y3_binary_accuracy: 0.8625 - val_y3_binary_loss: 0.3407
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 119ms/step - loss: 1.0333 - y1_classifier_accuracy: 0.7510 - y1_classifier_loss: 0.6079 - y2_regressor_loss: 0.0574 - y2_regressor_mae: 0.1343 - y3_binary_accuracy: 0.8306 - y3_binary_loss: 0.3680 - val_loss: 0.8876 - val_y1_classifier_accuracy: 0.7969 - val_y1_classifier_loss: 0.5002 - val_y2_regressor_loss: 0.0588 - val_y2_regressor_mae: 0.1395 - val_y3_binary_accuracy: 0.8813 - val_y3_binary_loss: 0.3286
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.8943 - y1_classifier_accuracy: 0.7847 - y1_classifier_loss: 0.5109 - y2_regressor_loss: 0.0467 - y2_regressor_mae: 0.1176 - y3_binary_accuracy: 0.8528 - y3_binary_loss: 0.3367 - val_loss: 0.7894 - val_y1_classifier_accuracy: 0.8125 - val_y1_classifier_loss: 0.4722 - val_y2_regressor_loss: 0.0279 - val_y2_regressor_mae: 0.0857 - val_y3_binary_accuracy: 0.8969 - val_y3_binary_loss: 0.2893
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.8504 - y1_classifier_accuracy: 0.7726 - y1_classifier_loss: 0.5112 - y2_regressor_loss: 0.0372 - y2_regressor_mae: 0.0994 - y3_binary_accuracy: 0.8823 - y3_binary_loss: 0.3019 - val_loss: 1.4446 - val_y1_classifier_accuracy: 0.6187 - val_y1_classifier_loss: 0.9169 - val_y2_regressor_loss: 0.0839 - val_y2_regressor_mae: 0.1655 - val_y3_binary_accuracy: 0.8500 - val_y3_binary_loss: 0.4438
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.8713 - y1_classifier_accuracy: 0.7691 - y1_classifier_loss: 0.5380 - y2_regressor_loss: 0.0483 - y2_regressor_mae: 0.1102 - y3_binary_accuracy: 0.8896 - y3_binary_loss: 0.2850 - val_loss: 0.7261 - val_y1_classifier_accuracy: 0.7812 - val_y1_classifier_loss: 0.4566 - val_y2_regressor_loss: 0.0342 - val_y2_regressor_mae: 0.0963 - val_y3_binary_accuracy: 0.9156 - val_y3_binary_loss: 0.2353
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.6604 - y1_classifier_accuracy: 0.8087 - y1_classifier_loss: 0.4304 - y2_regressor_loss: 0.0277 - y2_regressor_mae: 0.0810 - y3_binary_accuracy: 0.9271 - y3_binary_loss: 0.2022 - val_loss: 0.6083 - val_y1_classifier_accuracy: 0.8469 - val_y1_classifier_loss: 0.3919 - val_y2_regressor_loss: 0.0232 - val_y2_regressor_mae: 0.0721 - val_y3_binary_accuracy: 0.9344 - val_y3_binary_loss: 0.1932
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.6484 - y1_classifier_accuracy: 0.8132 - y1_classifier_loss: 0.4367 - y2_regressor_loss: 0.0322 - y2_regressor_mae: 0.0827 - y3_binary_accuracy: 0.9344 - y3_binary_loss: 0.1795 - val_loss: 0.6124 - val_y1_classifier_accuracy: 0.8062 - val_y1_classifier_loss: 0.4171 - val_y2_regressor_loss: 0.0306 - val_y2_regressor_mae: 0.0891 - val_y3_binary_accuracy: 0.9375 - val_y3_binary_loss: 0.1647
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.6270 - y1_classifier_accuracy: 0.8139 - y1_classifier_loss: 0.4306 - y2_regressor_loss: 0.0372 - y2_regressor_mae: 0.0893 - y3_binary_accuracy: 0.9410 - y3_binary_loss: 0.1592 - val_loss: 0.8683 - val_y1_classifier_accuracy: 0.7469 - val_y1_classifier_loss: 0.6268 - val_y2_regressor_loss: 0.0215 - val_y2_regressor_mae: 0.0665 - val_y3_binary_accuracy: 0.9094 - val_y3_binary_loss: 0.2200
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.5408 - y1_classifier_accuracy: 0.8465 - y1_classifier_loss: 0.3673 - y2_regressor_loss: 0.0245 - y2_regressor_mae: 0.0699 - y3_binary_accuracy: 0.9486 - y3_binary_loss: 0.1490 - val_loss: 0.4604 - val_y1_classifier_accuracy: 0.8781 - val_y1_classifier_loss: 0.3319 - val_y2_regressor_loss: 0.0144 - val_y2_regressor_mae: 0.0538 - val_y3_binary_accuracy: 0.9625 - val_y3_binary_loss: 0.1142
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.5342 - y1_classifier_accuracy: 0.8406 - y1_classifier_loss: 0.3786 - y2_regressor_loss: 0.0236 - y2_regressor_mae: 0.0667 - y3_binary_accuracy: 0.9566 - y3_binary_loss: 0.1319 - val_loss: 0.4579 - val_y1_classifier_accuracy: 0.8781 - val_y1_classifier_loss: 0.3363 - val_y2_regressor_loss: 0.0245 - val_y2_regressor_mae: 0.0716 - val_y3_binary_accuracy: 0.9812 - val_y3_binary_loss: 0.0972
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.5501 - y1_classifier_accuracy: 0.8503 - y1_classifier_loss: 0.3650 - y2_regressor_loss: 0.0282 - y2_regressor_mae: 0.0703 - y3_binary_accuracy: 0.9438 - y3_binary_loss: 0.1569 - val_loss: 0.7474 - val_y1_classifier_accuracy: 0.8156 - val_y1_classifier_loss: 0.4320 - val_y2_regressor_loss: 0.0279 - val_y2_regressor_mae: 0.0827 - val_y3_binary_accuracy: 0.8656 - val_y3_binary_loss: 0.2875
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.5067 - y1_classifier_accuracy: 0.8556 - y1_classifier_loss: 0.3364 - y2_regressor_loss: 0.0232 - y2_regressor_mae: 0.0627 - y3_binary_accuracy: 0.9524 - y3_binary_loss: 0.1471 - val_loss: 0.4257 - val_y1_classifier_accuracy: 0.8375 - val_y1_classifier_loss: 0.3110 - val_y2_regressor_loss: 0.0144 - val_y2_regressor_mae: 0.0498 - val_y3_binary_accuracy: 0.9781 - val_y3_binary_loss: 0.1002
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.3540 - y1_classifier_accuracy: 0.8976 - y1_classifier_loss: 0.2615 - y2_regressor_loss: 0.0135 - y2_regressor_mae: 0.0495 - y3_binary_accuracy: 0.9823 - y3_binary_loss: 0.0790 - val_loss: 0.3924 - val_y1_classifier_accuracy: 0.8625 - val_y1_classifier_loss: 0.2846 - val_y2_regressor_loss: 0.0176 - val_y2_regressor_mae: 0.0544 - val_y3_binary_accuracy: 0.9781 - val_y3_binary_loss: 0.0903
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.3709 - y1_classifier_accuracy: 0.8965 - y1_classifier_loss: 0.2692 - y2_regressor_loss: 0.0126 - y2_regressor_mae: 0.0437 - y3_binary_accuracy: 0.9736 - y3_binary_loss: 0.0890 - val_loss: 0.5759 - val_y1_classifier_accuracy: 0.8281 - val_y1_classifier_loss: 0.4054 - val_y2_regressor_loss: 0.0215 - val_y2_regressor_mae: 0.0619 - val_y3_binary_accuracy: 0.9594 - val_y3_binary_loss: 0.1489
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - loss: 0.5745 - y1_classifier_accuracy: 0.8358 - y1_classifier_loss: 0.3990 - y2_regressor_loss: 0.0343 - y2_regressor_mae: 0.0779 - y3_binary_accuracy: 0.9507 - y3_binary_loss: 0.1412 - val_loss: 0.3957 - val_y1_classifier_accuracy: 0.8750 - val_y1_classifier_loss: 0.2861 - val_y2_regressor_loss: 0.0163 - val_y2_regressor_mae: 0.0551 - val_y3_binary_accuracy: 0.9625 - val_y3_binary_loss: 0.0933
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.3163 - y1_classifier_accuracy: 0.9146 - y1_classifier_loss: 0.2418 - y2_regressor_loss: 0.0108 - y2_regressor_mae: 0.0405 - y3_binary_accuracy: 0.9840 - y3_binary_loss: 0.0637 - val_loss: 0.2715 - val_y1_classifier_accuracy: 0.9062 - val_y1_classifier_loss: 0.2149 - val_y2_regressor_loss: 0.0152 - val_y2_regressor_mae: 0.0437 - val_y3_binary_accuracy: 0.9969 - val_y3_binary_loss: 0.0414
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2620 - y1_classifier_accuracy: 0.9233 - y1_classifier_loss: 0.2059 - y2_regressor_loss: 0.0088 - y2_regressor_mae: 0.0351 - y3_binary_accuracy: 0.9906 - y3_binary_loss: 0.0472 - val_loss: 0.2973 - val_y1_classifier_accuracy: 0.8969 - val_y1_classifier_loss: 0.2272 - val_y2_regressor_loss: 0.0110 - val_y2_regressor_mae: 0.0360 - val_y3_binary_accuracy: 0.9875 - val_y3_binary_loss: 0.0591
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.6587 - y1_classifier_accuracy: 0.8167 - y1_classifier_loss: 0.4820 - y2_regressor_loss: 0.0391 - y2_regressor_mae: 0.0837 - y3_binary_accuracy: 0.9510 - y3_binary_loss: 0.1376 - val_loss: 0.3343 - val_y1_classifier_accuracy: 0.9406 - val_y1_classifier_loss: 0.2524 - val_y2_regressor_loss: 0.0243 - val_y2_regressor_mae: 0.0723 - val_y3_binary_accuracy: 0.9969 - val_y3_binary_loss: 0.0576
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 123ms/step - loss: 0.3419 - y1_classifier_accuracy: 0.9181 - y1_classifier_loss: 0.2568 - y2_regressor_loss: 0.0145 - y2_regressor_mae: 0.0513 - y3_binary_accuracy: 0.9774 - y3_binary_loss: 0.0706 - val_loss: 0.5149 - val_y1_classifier_accuracy: 0.8469 - val_y1_classifier_loss: 0.3513 - val_y2_regressor_loss: 0.0216 - val_y2_regressor_mae: 0.0626 - val_y3_binary_accuracy: 0.9625 - val_y3_binary_loss: 0.1420
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.2966 - y1_classifier_accuracy: 0.9285 - y1_classifier_loss: 0.2219 - y2_regressor_loss: 0.0187 - y2_regressor_mae: 0.0502 - y3_binary_accuracy: 0.9844 - y3_binary_loss: 0.0560 - val_loss: 0.3892 - val_y1_classifier_accuracy: 0.8938 - val_y1_classifier_loss: 0.2716 - val_y2_regressor_loss: 0.0421 - val_y2_regressor_mae: 0.0868 - val_y3_binary_accuracy: 0.9750 - val_y3_binary_loss: 0.0755
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.2924 - y1_classifier_accuracy: 0.9222 - y1_classifier_loss: 0.2216 - y2_regressor_loss: 0.0189 - y2_regressor_mae: 0.0533 - y3_binary_accuracy: 0.9847 - y3_binary_loss: 0.0520 - val_loss: 0.2668 - val_y1_classifier_accuracy: 0.9187 - val_y1_classifier_loss: 0.2285 - val_y2_regressor_loss: 0.0035 - val_y2_regressor_mae: 0.0245 - val_y3_binary_accuracy: 0.9937 - val_y3_binary_loss: 0.0348
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.2673 - y1_classifier_accuracy: 0.9288 - y1_classifier_loss: 0.2094 - y2_regressor_loss: 0.0126 - y2_regressor_mae: 0.0431 - y3_binary_accuracy: 0.9889 - y3_binary_loss: 0.0453 - val_loss: 0.2945 - val_y1_classifier_accuracy: 0.9125 - val_y1_classifier_loss: 0.2569 - val_y2_regressor_loss: 0.0110 - val_y2_regressor_mae: 0.0367 - val_y3_binary_accuracy: 0.9969 - val_y3_binary_loss: 0.0266
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2590 - y1_classifier_accuracy: 0.9378 - y1_classifier_loss: 0.2003 - y2_regressor_loss: 0.0140 - y2_regressor_mae: 0.0420 - y3_binary_accuracy: 0.9885 - y3_binary_loss: 0.0448 - val_loss: 0.3018 - val_y1_classifier_accuracy: 0.9438 - val_y1_classifier_loss: 0.2106 - val_y2_regressor_loss: 0.0334 - val_y2_regressor_mae: 0.0664 - val_y3_binary_accuracy: 0.9844 - val_y3_binary_loss: 0.0578
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.2653 - y1_classifier_accuracy: 0.9302 - y1_classifier_loss: 0.2003 - y2_regressor_loss: 0.0120 - y2_regressor_mae: 0.0418 - y3_binary_accuracy: 0.9830 - y3_binary_loss: 0.0529 - val_loss: 0.1778 - val_y1_classifier_accuracy: 0.9781 - val_y1_classifier_loss: 0.1523 - val_y2_regressor_loss: 0.0042 - val_y2_regressor_mae: 0.0263 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0213
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2273 - y1_classifier_accuracy: 0.9497 - y1_classifier_loss: 0.1787 - y2_regressor_loss: 0.0125 - y2_regressor_mae: 0.0423 - y3_binary_accuracy: 0.9913 - y3_binary_loss: 0.0361 - val_loss: 0.2426 - val_y1_classifier_accuracy: 0.9187 - val_y1_classifier_loss: 0.2072 - val_y2_regressor_loss: 0.0082 - val_y2_regressor_mae: 0.0348 - val_y3_binary_accuracy: 0.9937 - val_y3_binary_loss: 0.0273
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.2052 - y1_classifier_accuracy: 0.9469 - y1_classifier_loss: 0.1631 - y2_regressor_loss: 0.0123 - y2_regressor_mae: 0.0415 - y3_binary_accuracy: 0.9944 - y3_binary_loss: 0.0298 - val_loss: 0.1983 - val_y1_classifier_accuracy: 0.9500 - val_y1_classifier_loss: 0.1690 - val_y2_regressor_loss: 0.0133 - val_y2_regressor_mae: 0.0478 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0160
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2587 - y1_classifier_accuracy: 0.9330 - y1_classifier_loss: 0.1878 - y2_regressor_loss: 0.0121 - y2_regressor_mae: 0.0411 - y3_binary_accuracy: 0.9806 - y3_binary_loss: 0.0588 - val_loss: 0.1787 - val_y1_classifier_accuracy: 0.9656 - val_y1_classifier_loss: 0.1285 - val_y2_regressor_loss: 0.0129 - val_y2_regressor_mae: 0.0349 - val_y3_binary_accuracy: 0.9906 - val_y3_binary_loss: 0.0372
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.2077 - y1_classifier_accuracy: 0.9469 - y1_classifier_loss: 0.1652 - y2_regressor_loss: 0.0073 - y2_regressor_mae: 0.0306 - y3_binary_accuracy: 0.9896 - y3_binary_loss: 0.0352 - val_loss: 0.1619 - val_y1_classifier_accuracy: 0.9500 - val_y1_classifier_loss: 0.1356 - val_y2_regressor_loss: 0.0048 - val_y2_regressor_mae: 0.0196 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0216
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.1562 - y1_classifier_accuracy: 0.9569 - y1_classifier_loss: 0.1268 - y2_regressor_loss: 0.0058 - y2_regressor_mae: 0.0248 - y3_binary_accuracy: 0.9944 - y3_binary_loss: 0.0236 - val_loss: 0.1265 - val_y1_classifier_accuracy: 0.9625 - val_y1_classifier_loss: 0.1110 - val_y2_regressor_loss: 0.0014 - val_y2_regressor_mae: 0.0134 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0141
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.1503 - y1_classifier_accuracy: 0.9583 - y1_classifier_loss: 0.1198 - y2_regressor_loss: 0.0064 - y2_regressor_mae: 0.0278 - y3_binary_accuracy: 0.9941 - y3_binary_loss: 0.0241 - val_loss: 0.1550 - val_y1_classifier_accuracy: 0.9219 - val_y1_classifier_loss: 0.1357 - val_y2_regressor_loss: 0.0051 - val_y2_regressor_mae: 0.0223 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0142
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2230 - y1_classifier_accuracy: 0.9361 - y1_classifier_loss: 0.1696 - y2_regressor_loss: 0.0160 - y2_regressor_mae: 0.0456 - y3_binary_accuracy: 0.9899 - y3_binary_loss: 0.0374 - val_loss: 0.1604 - val_y1_classifier_accuracy: 0.9563 - val_y1_classifier_loss: 0.1263 - val_y2_regressor_loss: 0.0040 - val_y2_regressor_mae: 0.0254 - val_y3_binary_accuracy: 0.9937 - val_y3_binary_loss: 0.0301
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.1438 - y1_classifier_accuracy: 0.9667 - y1_classifier_loss: 0.1116 - y2_regressor_loss: 0.0107 - y2_regressor_mae: 0.0321 - y3_binary_accuracy: 0.9951 - y3_binary_loss: 0.0215 - val_loss: 0.0906 - val_y1_classifier_accuracy: 0.9844 - val_y1_classifier_loss: 0.0766 - val_y2_regressor_loss: 0.0018 - val_y2_regressor_mae: 0.0138 - val_y3_binary_accuracy: 1.0000 - val_y3_binary_loss: 0.0122
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.1689 - y1_classifier_accuracy: 0.9469 - y1_classifier_loss: 0.1319 - y2_regressor_loss: 0.0110 - y2_regressor_mae: 0.0333 - y3_binary_accuracy: 0.9937 - y3_binary_loss: 0.0260 - val_loss: 0.2214 - val_y1_classifier_accuracy: 0.9531 - val_y1_classifier_loss: 0.1638 - val_y2_regressor_loss: 0.0101 - val_y2_regressor_mae: 0.0355 - val_y3_binary_accuracy: 0.9906 - val_y3_binary_loss: 0.0475
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 0.2976 - y1_classifier_accuracy: 0.9198 - y1_classifier_loss: 0.2040 - y2_regressor_loss: 0.0240 - y2_regressor_mae: 0.0597 - y3_binary_accuracy: 0.9792 - y3_binary_loss: 0.0696 - val_loss: 0.1806 - val_y1_classifier_accuracy: 0.9594 - val_y1_classifier_loss: 0.1285 - val_y2_regressor_loss: 0.0100 - val_y2_regressor_mae: 0.0402 - val_y3_binary_accuracy: 0.9844 - val_y3_binary_loss: 0.0421
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.1931 - y1_classifier_accuracy: 0.9503 - y1_classifier_loss: 0.1422 - y2_regressor_loss: 0.0120 - y2_regressor_mae: 0.0405 - y3_binary_accuracy: 0.9903 - y3_binary_loss: 0.0389 - val_loss: 0.1126 - val_y1_classifier_accuracy: 0.9563 - val_y1_classifier_loss: 0.0919 - val_y2_regressor_loss: 0.0043 - val_y2_regressor_mae: 0.0235 - val_y3_binary_accuracy: 0.9969 - val_y3_binary_loss: 0.0164
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - loss: 0.1357 - y1_classifier_accuracy: 0.9608 - y1_classifier_loss: 0.1119 - y2_regressor_loss: 0.0070 - y2_regressor_mae: 0.0267 - y3_binary_accuracy: 0.9962 - y3_binary_loss: 0.0168 - val_loss: 0.3755 - val_y1_classifier_accuracy: 0.8625 - val_y1_classifier_loss: 0.3028 - val_y2_regressor_loss: 0.0101 - val_y2_regressor_mae: 0.0329 - val_y3_binary_accuracy: 0.9781 - val_y3_binary_loss: 0.0626
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 0.2799 - y1_classifier_accuracy: 0.9278 - y1_classifier_loss: 0.1793 - y2_regressor_loss: 0.0276 - y2_regressor_mae: 0.0728 - y3_binary_accuracy: 0.9750 - y3_binary_loss: 0.0730 - val_loss: 0.2107 - val_y1_classifier_accuracy: 0.9094 - val_y1_classifier_loss: 0.1598 - val_y2_regressor_loss: 0.0081 - val_y2_regressor_mae: 0.0363 - val_y3_binary_accuracy: 0.9937 - val_y3_binary_loss: 0.0428
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 35.

# %%
import matplotlib.pyplot as plt

# Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['y1_classifier_loss'], label='Training Loss')
plt.plot(history.history['val_y1_classifier_loss'], label='Validation Loss')

plt.plot(history.history['y2_regressor_loss'], label='Training Loss')
plt.plot(history.history['val_y2_regressor_loss'], label='Validation Loss')

plt.plot(history.history['y3_binary_loss'], label='Training Loss')
plt.plot(history.history['val_y3_binary_loss'], label='Validation Loss')
plt.title('Loss vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot Training and Validation Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['y1_classifier_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_y1_classifier_accuracy'], label='Validation Accuracy')

plt.plot(history.history['y2_regressor_mae'], label='Training Accuracy')
plt.plot(history.history['val_y2_regressor_mae'], label='Validation Accuracy')

plt.plot(history.history['y3_binary_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_y3_binary_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0,1])
plt.legend()
plt.grid(True)
plt.show()



model.save("lstm_multilabel_multiend_classifier2.h5")
np.save("scaler_minmax2.npy", scaler.data_min_)
print("\nModel saved as lstm_multilabel_multiend_classifier2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as lstm_multilabel_multiend_classifier2.h5
